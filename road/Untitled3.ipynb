# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
input_data_file = "Delivery truck trip data.xlsx"
train_data = pd.read_excel(input_data_file)
train_data.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#      GpsProvider           BookingID Market/Regular           BookingID_Date  \
# 0  CONSENT TRACK  MVCV0000927/082021          Market 2020-08-17 14:59:01.000
# 1        VAMOSYS  VCV00014271/082021         Regular 2020-08-27 16:22:22.827
# 2  CONSENT TRACK  VCV00014382/082021         Regular 2020-08-27 17:59:24.987
# 3        VAMOSYS  VCV00014743/082021         Regular 2020-08-28 00:48:24.503
# 4        VAMOSYS  VCV00014744/082021         Regular 2020-08-28 01:23:19.243
#
#    vehicle_no                                    Origin_Location  \
# 0    KA590408               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  TN30BC5917  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# ...

# %%
train_data.drop_duplicates(inplace=True)
train_data.shape
# Out:
# (6880, 32)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6880 entries, 0 to 6879
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5927 non-null   object
#  1   BookingID                           6880 non-null   object
#  2   Market/Regular                      6880 non-null   object
#  3   BookingID_Date                      6880 non-null   datetime64[ns]
#  4   vehicle_no                          6880 non-null   object
#  5   Origin_Location                     6880 non-null   object
#  6   Destination_Location                6880 non-null   object
#  7   Org_lat_lon                         6880 non-null   object
#  8   Des_lat_lon                         6880 non-null   object
#  9   Data_Ping_time                      5927 non-null   datetime64[ns]
#  10  Planned_ETA                         6880 non-null   datetime64[ns]
# ...

# %%
train_data.drop(train_data.columns[2],axis=1,inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6880 entries, 0 to 6879
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5927 non-null   object
#  1   BookingID                           6880 non-null   object
#  2   BookingID_Date                      6880 non-null   datetime64[ns]
#  3   vehicle_no                          6880 non-null   object
#  4   Origin_Location                     6880 non-null   object
#  5   Destination_Location                6880 non-null   object
#  6   Org_lat_lon                         6880 non-null   object
#  7   Des_lat_lon                         6880 non-null   object
#  8   Data_Ping_time                      5927 non-null   datetime64[ns]
#  9   Planned_ETA                         6880 non-null   datetime64[ns]
#  10  Current_Location                    5916 non-null   object
# ...

# %%
train_data.drop(train_data.columns[[15,16,26,27,28,29,30]],axis=1,inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6880 entries, 0 to 6879
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5927 non-null   object
#  1   BookingID                           6880 non-null   object
#  2   BookingID_Date                      6880 non-null   datetime64[ns]
#  3   vehicle_no                          6880 non-null   object
#  4   Origin_Location                     6880 non-null   object
#  5   Destination_Location                6880 non-null   object
#  6   Org_lat_lon                         6880 non-null   object
#  7   Des_lat_lon                         6880 non-null   object
#  8   Data_Ping_time                      5927 non-null   datetime64[ns]
#  9   Planned_ETA                         6880 non-null   datetime64[ns]
#  10  Current_Location                    5916 non-null   object
# ...

# %%
train_data=train_data.dropna()
train_data
# Out:
#         GpsProvider     BookingID      BookingID_Date  vehicle_no  \
# 417   CONSENT TRACK  AEIBK2026966 2020-08-21 19:11:26  UP17AT5999
# 418   CONSENT TRACK  AEIBK2026766 2020-08-20 17:57:29  UP17AT8988
# 419   CONSENT TRACK  AEIBK2026765 2020-08-20 17:53:05  UP78FN4706
# 421   CONSENT TRACK  AEIBK2026772 2020-08-20 18:23:33   UP17T8250
# 422   CONSENT TRACK  AEIBK2026929 2020-08-21 18:15:12  UP17AT4570
# ...             ...           ...                 ...         ...
# 3761  CONSENT TRACK  AEIBK1910732 2019-12-30 18:23:49   OD14L7676
# 3763  CONSENT TRACK  AEIBK2011419 2020-01-07 14:56:40  AP16TY1859
# 3835  CONSENT TRACK  AEIBK1910132 2019-12-26 19:56:20   NL01D5206
# 3876  CONSENT TRACK  AEIBK1909663 2019-12-21 18:48:49   NL01K7906
# 4319  CONSENT TRACK  AEIBK1906955 2019-11-30 15:10:27  GJ15UU7437
#
#                                Origin_Location  \
# 417   Ramte Ram Road, Ghaziabad, Uttar Pradesh
# 418   Ramte Ram Road, Ghaziabad, Uttar Pradesh
# ...

# %%
# input_data_file = "cleartrip_com-travel_sample.csv"
df = pd.read_csv('cleartrip_com-travel_sample.csv')
df
# Out:
#                                                 address  \
# 0                                   9th Mile, Kalimpong
# 1                    New Kalimati Road, Kasidih, Sakchi
# 2     Opposite Nagarpalika, Near Pushkarna Bera, Pos...
# 3         11-3-11 Veterinary Hospital road,Ramarao peta
# 4                      Near Fort First Gate, Dhibbapara
# ...                                                 ...
# 4995                                     Nagrath Square
# 4996  Flat 305, Anand Nilayam Apartments Anndorai Ch...
# 4997                     Beside Google Office, Kondapur
# 4998  Thumkunta Village, Karimnagar Main Road Shamee...
# 4999  Near Fort 1st Gate and Behind Shiv Road, Jaisa...
#
#                             area        city  cleartrip_seller_rating country  \
# 0          Rishi Road-Highway 12   Kalimpong                      NaN   INDIA
# 1                            NaN  Jamshedpur                      NaN   INDIA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   address                    4995 non-null   object
#  1   area                       4909 non-null   object
#  2   city                       5000 non-null   object
#  3   cleartrip_seller_rating    427 non-null    float64
#  4   country                    5000 non-null   object
#  5   crawl_date                 5000 non-null   object
#  6   hotel_description          4655 non-null   object
#  7   hotel_facilities           4964 non-null   object
#  8   hotel_star_rating          4746 non-null   object
#  9   image_count                5000 non-null   int64
#  10  image_urls                 4995 non-null   object
#  11  landmark                   5000 non-null   object
#  12  latitude                   4883 non-null   float64
# ...

# %%
df=df.drop('similar_hotel',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   address                    4995 non-null   object
#  1   area                       4909 non-null   object
#  2   city                       5000 non-null   object
#  3   cleartrip_seller_rating    427 non-null    float64
#  4   country                    5000 non-null   object
#  5   crawl_date                 5000 non-null   object
#  6   hotel_description          4655 non-null   object
#  7   hotel_facilities           4964 non-null   object
#  8   hotel_star_rating          4746 non-null   object
#  9   image_count                5000 non-null   int64
#  10  image_urls                 4995 non-null   object
#  11  landmark                   5000 non-null   object
#  12  latitude                   4883 non-null   float64
# ...

# %%
df=df.drop(df.columns[[5,6,7,8,9,10,15,17,18,19,20,21,23,24,25,26,28,29,30,31]],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   address                  4995 non-null   object
#  1   area                     4909 non-null   object
#  2   city                     5000 non-null   object
#  3   cleartrip_seller_rating  427 non-null    float64
#  4   country                  5000 non-null   object
#  5   landmark                 5000 non-null   object
#  6   latitude                 4883 non-null   float64
#  7   locality                 4909 non-null   object
#  8   longitude                4882 non-null   float64
#  9   property_id              5000 non-null   int64
#  10  room_count               5000 non-null   int64
#  11  tad_review_count         3582 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 468.9+ KB

# %%
df=df.drop(('cleartrip_seller_rating'),axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   address           4995 non-null   object
#  1   area              4909 non-null   object
#  2   city              5000 non-null   object
#  3   country           5000 non-null   object
#  4   landmark          5000 non-null   object
#  5   latitude          4883 non-null   float64
#  6   locality          4909 non-null   object
#  7   longitude         4882 non-null   float64
#  8   property_id       5000 non-null   int64
#  9   room_count        5000 non-null   int64
#  10  tad_review_count  3582 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 429.8+ KB

# %%
df=df.dropna()
df
# Out:
#                                                 address  \
# 3         11-3-11 Veterinary Hospital road,Ramarao peta
# 4                      Near Fort First Gate, Dhibbapara
# 5        High Court Colony, Jodhpur. Rajasthan (India).
# 6                  SCO 44 - 45, New Grain Market, Kalka
# 7                                2-18 A6, Near Seashore
# ...                                                 ...
# 4994      Pareek College Road, Banipark, Near Lal Pyaoo
# 4995                                     Nagrath Square
# 4997                     Beside Google Office, Kondapur
# 4998  Thumkunta Village, Karimnagar Main Road Shamee...
# 4999  Near Fort 1st Gate and Behind Shiv Road, Jaisa...
#
#                                 area         city country  \
# 3                        Cinema Road     Kakinada   INDIA
# 4         Near Jaisalmer Golden Fort    Jaisalmer   INDIA
# 5               Ratanada Petrol Pump      Jodhpur   INDIA
# ...

# %%
df1=train_data.head(10)
df1
# Out:
#        GpsProvider     BookingID      BookingID_Date  vehicle_no  \
# 417  CONSENT TRACK  AEIBK2026966 2020-08-21 19:11:26  UP17AT5999
# 418  CONSENT TRACK  AEIBK2026766 2020-08-20 17:57:29  UP17AT8988
# 419  CONSENT TRACK  AEIBK2026765 2020-08-20 17:53:05  UP78FN4706
# 421  CONSENT TRACK  AEIBK2026772 2020-08-20 18:23:33   UP17T8250
# 422  CONSENT TRACK  AEIBK2026929 2020-08-21 18:15:12  UP17AT4570
# 426  CONSENT TRACK  AEIBK2026439 2020-08-18 17:34:01  UP17AT5999
# 447  CONSENT TRACK  AEIBK2026440 2020-08-18 17:35:40  UP17AT4210
# 450  CONSENT TRACK  AEIBK2026442 2020-08-18 17:41:56  UP17AT4570
# 455  CONSENT TRACK  AEIBK2026437 2020-08-18 17:28:42  UP17AT0059
# 456  CONSENT TRACK  AEIBK2026438 2020-08-18 17:30:06   UP17T9436
#
#                               Origin_Location  \
# 417  Ramte Ram Road, Ghaziabad, Uttar Pradesh
# 418  Ramte Ram Road, Ghaziabad, Uttar Pradesh
# 419  Ramte Ram Road, Ghaziabad, Uttar Pradesh
# 421  Ramte Ram Road, Ghaziabad, Uttar Pradesh
# ...

# %%
from math import radians, cos, sin, asin, sqrt
def distance(lat1, lat2, lon1, lon2):
     
    lon1 = radians(lon1)
    lon2 = radians(lon2)
    lat1 = radians(lat1)
    lat2 = radians(lat2)
      
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
 
    c = 2 * asin(sqrt(a))
    
    # Radius of earth in kilometers. Use 3956 for miles
    r = 6371
      
    return(c * r)

for i in range(0,10):
  instance=df1.iloc[i]
  instance=instance.tolist()

  x=instance[6]
  y=instance[7]
  a=x.split(",")
  b=y.split(",")
  lat1 = float(a[0])
  lat2 = float(b[0])
  lon1 = float(a[0])
  lon2 =  float(b[1])

  #converting distance to integer to run loop and also because some amount of error is tolerable
  dist=int(distance(lat1, lat2, lon1, lon2))

  rest_stops=0

  for kms_gone_by in range(0,dist):
    if(kms_gone_by%500==0):
      rest_stops+=1

  print("driver ",instance[22]," needs ",rest_stops," stops on the way from ",instance[4]," to ",instance[5])
# Out:
# driver  Yogesh Kumar  needs  11  stops on the way from  Ramte Ram Road, Ghaziabad, Uttar Pradesh  to  Dadri, Gautam Buddha Nagar, Uttar Pradesh
# driver  Mustkeem Khan  needs  10  stops on the way from  Ramte Ram Road, Ghaziabad, Uttar Pradesh  to  Bhikki, Muzaffarnagar, Uttar Pradesh
# driver  Shakeel  needs  10  stops on the way from  Ramte Ram Road, Ghaziabad, Uttar Pradesh  to  Shah Mohiuddinpur, Ghaziabad, Uttar Pradesh
# driver  Satendra Kumar Tyagi  needs  10  stops on the way from  Ramte Ram Road, Ghaziabad, Uttar Pradesh  to  Muzakkipur, Meerut, Uttar Pradesh
# driver  Salman  needs  11  stops on the way from  Ramte Ram Road, Ghaziabad, Uttar Pradesh  to  Dadri, Gautam Buddha Nagar, Uttar Pradesh
# driver  Sabu Khan  needs  10  stops on the way from  Ramte Ram Road, Ghaziabad, Uttar Pradesh  to  Shah Mohiuddinpur, Ghaziabad, Uttar Pradesh
# ...
